# %%
import pandas as pd

messages_path = "data/youtube_links.jsonl"
titles_path = "data/preprocessed_english_titles.csv"
infos_path = "data/youtube_titulos_saida.csv"
output_path = "data/youtube_telegram_cross.csv"

df_titles = pd.read_csv(titles_path)
df_infos = pd.read_csv(infos_path)
df_telegram = pd.read_json(messages_path, lines=True)

print(f"Preprocessed titles/descriptions: {len(df_titles)} entries")
display(df_titles.head())
print(f"Video metrics/metadata: {len(df_infos)} entries")
display(df_infos.head())
print(f"Telegram message occurrences: {len(df_telegram)} entries")
display(df_telegram.head())
# Out:
# Preprocessed titles/descriptions: 686626 entries
#    Unnamed: 0     video_id                                              title  \
# 0           0  jEKzQV5oajY  Free bus travel for migrants scrapped. For 5 m...
# 1           1  xrGGce8cmx8                         What is Spiritual Warfare?
# 2           2  uaozGpSc4nc                              80 Putins Have Layers
# 3           3  A59ftbhsQUE  𝐆𝐀𝐋𝐀𝐂𝐓𝐈𝐂 𝐀𝐋𝐋𝐈𝐀𝐍𝐂𝐄 𝐌𝐄𝐒𝐒𝐀𝐆𝐄|𝐁𝐈𝐆 𝐍𝐄𝐖𝐒!~𝐑𝐄𝐌𝐀𝐈𝐍 𝐀𝐋𝐄...
# 4           4  AKU0RokegSo  Los Angeles rain: Studio City homes evacuated ...
#
#                                          description  \
# 0                                                NaN
# 1  This charge I commit unto thee, son Timothy, a...
# 2  In February 2024, Tucker Carlson stood in fron...
# 3  #pleiadians #5dimension #ashtar\n#pleiadians #...
# 4  An atmospheric river storm has caused mudslide...
#
#                                    title_description lang  \
# 0  Free bus travel for migrants scrapped. For 5 m...   en
# ...

# %% [markdown]
# ### **1. Extracting the IDs from the links**

# %%
import re

def get_ID(url:str) -> str:
    #match = re.search(
    #        r"(?:v=|youtu\.be/|/v/|/embed/|/live/|/shorts/)([a-zA-Z0-9_-]{11})",
    #        url
    #    )
    match = re.search(
                r'(?:v=|\/|be\/|embed\/|shorts\/|watch\?v=)([a-zA-Z0-9_-]{11})',
                url
            )
    if match:
        return match.group(1)
    return None

# %%
import gzip
import json

objects = []
with open(messages_path, "rt") as f:
    for line in f:
        obj = json.loads(line)
        obj["id"] = get_ID(obj["url"])
        objects.append(obj)

# %%
with open(messages_path, "wt") as f:
    for obj in objects:
        f.write(json.dumps(obj) + "\n")

# %% [markdown]
# ___
# ### **2. Combining the interesting columns**

# %% [markdown]
# #### *2.1 Combining with df_titles*

# %%
df_final = pd.DataFrame({
    "video_id": df_titles["video_id"],
    "text": df_titles["clean_text"]
})

# %% [markdown]
# #### *2.2 Combining with df_infos*

# %%
df_final = df_final.merge(
    df_infos[["video_id", "channel_title", "published_at", "view_count", "like_count", "comment_count"]],
    on="video_id",
    how="left"
)

# %% [markdown]
# #### *2.3 Combining with df_telegram*
# But this has duplicate IDs, because different links can lead to the same ID, so that needs to be fixed first.

# %%
counts = df_telegram["id"].value_counts()
duplicates = counts[counts > 1]
print(duplicates)
# Out:
# id
# _YIe_4LRQfI    306
# hBMoPUAeLnY    284
# c5wnRebTKKY    271
# 9-zF54xbFw0    180
# 8sEsfotldIY    145
#               ...
# pBDI7xv__Fo      2
# 1fsKvW8fcDw      2
# p5attvG06uQ      2
# KFppEuJRTO4      2
# o821QX5LFpg      2
# Name: count, Length: 235500, dtype: int64

# %%
video_id = "o821QX5LFpg"

# Filtra apenas as linhas com esse video_id
occurrences = df_telegram[df_telegram["id"] == video_id]

# Exibe todas as ocorrências
display(occurrences)
display(occurrences["occurrences"].tolist())
# Out:
#                                                      url  \
# 142450  https://youtu.be/o821QX5LFpg?si=DDetjzACmDqnrMra
# 872570  https://youtu.be/o821QX5LFpg?si=bT00jO37-EOlT7ba
#
#                                               occurrences           id
# 142450  [{'id': 11707, 'folder': 'channel_1577438065',...  o821QX5LFpg
# 872570  [{'id': 10923, 'folder': 'channel_1385694192',...  o821QX5LFpg
# [[{'id': 11707, 'folder': 'channel_1577438065', 'date': '2023-11-30'}],
#  [{'id': 10923, 'folder': 'channel_1385694192', 'date': '2023-12-02'}]]

# %%
df_telegram = df_telegram.rename(columns={"id": "video_id"})

#Como um id pode ter mais de um link, agrupa essas ocorrências
df_telegram_unique = df_telegram.groupby("video_id")["occurrences"].apply(list).reset_index()

df_telegram_unique = (
    df_telegram.groupby("video_id")["occurrences"]
    .apply(lambda x: [item for sublist in x for item in sublist])
    .reset_index()
)

# %%
video_id = "o821QX5LFpg"

# Filtra apenas as linhas com esse video_id
occurrences = df_telegram_unique[df_telegram_unique["video_id"] == video_id]

# Exibe todas as ocorrências
display(occurrences)
display(occurrences["occurrences"].tolist())
# Out:
#             video_id                                        occurrences
# 1139383  o821QX5LFpg  [{'id': 11707, 'folder': 'channel_1577438065',...
# [[{'id': 11707, 'folder': 'channel_1577438065', 'date': '2023-11-30'},
#   {'id': 10923, 'folder': 'channel_1385694192', 'date': '2023-12-02'}]]

# %%
df_final = df_final.merge(
    df_telegram_unique,
    on="video_id",
    how="left"
)

# %%
display(df_final.head())
# Out:
#       video_id                                               text  \
# 0  jEKzQV5oajY                   free travel migrant scrap minute
# 1  xrGGce8cmx8  spiritual warfare charge commit unto thee timo...
# 2  uaozGpSc4nc  putin layer february tucker carlson stand onio...
# 3  A59ftbhsQUE  GALACTIC ALLIANCE MESSAGE NEWS REMAIN ALERT PR...
# 4  AKU0RokegSo  angeles rain studio city home evacuate mudslid...
#
#         channel_title          published_at  view_count  like_count  \
# 0           Joe Marsh  2024-04-10T15:05:37Z      1057.0       152.0
# 1               WWURD  2023-10-18T14:39:18Z        65.0         6.0
# 2      The Mosaic Ark  2024-02-22T07:30:05Z       330.0         8.0
# 3   GALACTIC ALLIANCE  2024-10-27T04:30:04Z       806.0       136.0
# 4  FOX 11 Los Angeles  2024-02-06T01:45:29Z     60863.0       406.0
#
#    comment_count                                        occurrences
# 0           32.0  [{'id': 1416, 'folder': 'channel_1556142220', ...
# ...

# %%
df_final.to_csv(output_path)

# %% [markdown]
# #### *2.3 Combining with toxics*

# %%
import pandas as pd

infos_path = "data/youtube_telegram_cross.csv"
toxics_path = "data/videos_with_toxics.csv"

df_final = pd.read_csv(infos_path)
df_toxics = pd.read_csv(toxics_path)

print(f"Cross Telegram Youtube: {len(df_final)} entries")
display(df_final.head())
print(f"Toxics of videos: {len(df_toxics)} entries")
display(df_toxics.head())
# Out:
# /tmp/ipykernel_1674323/479903545.py:7: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_toxics = pd.read_csv(toxics_path)
# Cross Telegram Youtube: 686626 entries
#    Unnamed: 0     video_id                                               text  \
# 0           0  jEKzQV5oajY                   free travel migrant scrap minute
# 1           1  xrGGce8cmx8  spiritual warfare charge commit unto thee timo...
# 2           2  uaozGpSc4nc  putin layer february tucker carlson stand onio...
# 3           3  A59ftbhsQUE  GALACTIC ALLIANCE MESSAGE NEWS REMAIN ALERT PR...
# 4           4  AKU0RokegSo  angeles rain studio city home evacuate mudslid...
#
#         channel_title          published_at  view_count  like_count  \
# 0           Joe Marsh  2024-04-10T15:05:37Z      1057.0       152.0
# 1               WWURD  2023-10-18T14:39:18Z        65.0         6.0
# 2      The Mosaic Ark  2024-02-22T07:30:05Z       330.0         8.0
# ...

# %%
cols = ["video_id", "toxicity", "severe_toxicity", "obscene", "threat", "insult", "identity_attack"]
df_final = df_final.merge(
    df_toxics[cols],
    on="video_id",
    how="left"
)
# Out:
# Merged dataset: 715920 entries
#    Unnamed: 0     video_id                                               text  \
# 0           0  jEKzQV5oajY                   free travel migrant scrap minute
# 1           1  xrGGce8cmx8  spiritual warfare charge commit unto thee timo...
# 2           2  uaozGpSc4nc  putin layer february tucker carlson stand onio...
# 3           3  A59ftbhsQUE  GALACTIC ALLIANCE MESSAGE NEWS REMAIN ALERT PR...
# 4           4  AKU0RokegSo  angeles rain studio city home evacuate mudslid...
#
#         channel_title          published_at  view_count  like_count  \
# 0           Joe Marsh  2024-04-10T15:05:37Z      1057.0       152.0
# 1               WWURD  2023-10-18T14:39:18Z        65.0         6.0
# 2      The Mosaic Ark  2024-02-22T07:30:05Z       330.0         8.0
# 3   GALACTIC ALLIANCE  2024-10-27T04:30:04Z       806.0       136.0
# 4  FOX 11 Los Angeles  2024-02-06T01:45:29Z     60863.0       406.0
#
# ...

# %%
df_final = df_final.drop_duplicates(subset='video_id', keep='first')
print(f"Merged dataset: {len(df_final)} entries")
display(df_final.head())
# Out:
# Merged dataset: 686626 entries

# %%
df_final.to_csv(infos_path)

# %% [markdown]
# ___
# ### **3. Creating the sample with topics**

# %%
import pandas as pd 

topics_path = "data/sample_df_with_topics.csv"
infos_path = "data/youtube_telegram_cross.csv"

df_final = pd.read_csv(infos_path)
df_topics = pd.read_csv(topics_path)

print(f"Cross Telegram Youtube: {len(df_final)} entries")
display(df_final.head())
print(f"Topics of videos: {len(df_topics)} entries")
display(df_topics.head())
# Out:
# Cross Telegram Youtube: 686626 entries
#    Unnamed: 0.1  Unnamed: 0     video_id  \
# 0             0           0  jEKzQV5oajY
# 1             1           1  xrGGce8cmx8
# 2             2           2  uaozGpSc4nc
# 3             3           3  A59ftbhsQUE
# 4             4           4  AKU0RokegSo
#
#                                                 text       channel_title  \
# 0                   free travel migrant scrap minute           Joe Marsh
# 1  spiritual warfare charge commit unto thee timo...               WWURD
# 2  putin layer february tucker carlson stand onio...      The Mosaic Ark
# 3  GALACTIC ALLIANCE MESSAGE NEWS REMAIN ALERT PR...   GALACTIC ALLIANCE
# 4  angeles rain studio city home evacuate mudslid...  FOX 11 Los Angeles
#
#            published_at  view_count  like_count  comment_count  \
# 0  2024-04-10T15:05:37Z      1057.0       152.0           32.0
# 1  2023-10-18T14:39:18Z        65.0         6.0            1.0
# ...

# %%
df_topics = df_topics.drop_duplicates(subset='video_id', keep='first')
print(f"Topics after removing duplicates: {len(df_topics)} entries")
# Out:
# Topics after removing duplicates: 67362 entries

# %%
df_topics[df_topics["topic"].isna()]
# Out:
#                                Unnamed: 0  \
# 28536                              208989
# 28537  Christmas song at the White House.
# 28538  Christmas song at the White House.
# 41925                              102614
# 65536                      - Cold Hearted
#
#                                                 video_id  \
# 28536                                        3ZjtWo8XDNQ
# 28537  Bidens Invite Nurses To Do Musical Number At W...
# 28538                                                 en
# 41925                                        aX_RHGSwfRE
# 65536  Subscribe to our channel for all your favourit...
#
#                                                    title  \
# 28536  Bidens Invite Nurses To Do Musical Number At W...
# 28537                                                NaN
# 28538  bidens invite nurse musical number white house...
# 41925                                        Paula Abdul
# 65536  Paula Abdul\r - Cold Hearted Subscribe to our ...
#
# ...

# %%
df_final = df_final.loc[:, ~df_final.columns.str.contains('^Unnamed')]
display(df_final.head())
# Out:
#       video_id                                               text  \
# 0  jEKzQV5oajY                   free travel migrant scrap minute
# 1  xrGGce8cmx8  spiritual warfare charge commit unto thee timo...
# 2  uaozGpSc4nc  putin layer february tucker carlson stand onio...
# 3  A59ftbhsQUE  GALACTIC ALLIANCE MESSAGE NEWS REMAIN ALERT PR...
# 4  AKU0RokegSo  angeles rain studio city home evacuate mudslid...
#
#         channel_title          published_at  view_count  like_count  \
# 0           Joe Marsh  2024-04-10T15:05:37Z      1057.0       152.0
# 1               WWURD  2023-10-18T14:39:18Z        65.0         6.0
# 2      The Mosaic Ark  2024-02-22T07:30:05Z       330.0         8.0
# 3   GALACTIC ALLIANCE  2024-10-27T04:30:04Z       806.0       136.0
# 4  FOX 11 Los Angeles  2024-02-06T01:45:29Z     60863.0       406.0
#
#    comment_count                                        occurrences  toxicity  \
# ...

# %%
df_final.to_csv(infos_path, index=False)

# %%
df = df_final.merge(df_topics[['video_id', 'topic']], on='video_id', how='left')
display(df.head())
# Out:
#       video_id                                               text  \
# 0  jEKzQV5oajY                   free travel migrant scrap minute
# 1  xrGGce8cmx8  spiritual warfare charge commit unto thee timo...
# 2  uaozGpSc4nc  putin layer february tucker carlson stand onio...
# 3  A59ftbhsQUE  GALACTIC ALLIANCE MESSAGE NEWS REMAIN ALERT PR...
# 4  AKU0RokegSo  angeles rain studio city home evacuate mudslid...
#
#         channel_title          published_at  view_count  like_count  \
# 0           Joe Marsh  2024-04-10T15:05:37Z      1057.0       152.0
# 1               WWURD  2023-10-18T14:39:18Z        65.0         6.0
# 2      The Mosaic Ark  2024-02-22T07:30:05Z       330.0         8.0
# 3   GALACTIC ALLIANCE  2024-10-27T04:30:04Z       806.0       136.0
# 4  FOX 11 Los Angeles  2024-02-06T01:45:29Z     60863.0       406.0
#
#    comment_count                                        occurrences  toxicity  \
# ...

# %%
df_sem_nan = df.dropna(subset=["topic"])
display(df_sem_nan.head())
print(f"Dataset after dropping NaN topics: {len(df_sem_nan)} entries")
# Out:
#        video_id                                               text  \
# 6   QKXr7N9c6Yo  roman islamic antichrist sonia azam explore bi...
# 7   qRFdVxvlXRY  kamala interview prove weak hope prove point w...
# 36  Y8KzbOkN_TM  money ttaakaa syllabus baire epbong welcome ep...
# 52  B5yS8olxa80  save israel jeremy gimpel live update frontlin...
# 54  JnvOJN5yF8s  kingdom planet official trailer cinemas yang b...
#
#                      channel_title          published_at  view_count  \
# 6                  Armageddon News  2021-10-11T16:36:04Z      2249.0
# 7             Real America's Voice  2024-10-08T14:57:04Z       498.0
# 36                   Your Bong Guy  2024-11-07T12:23:25Z   1198216.0
# 52                 thelandofisrael  2023-11-28T16:48:23Z     11835.0
# 54  20th Century Studios Indonesia  2024-02-12T01:24:59Z    211122.0
#
#     like_count  comment_count  \
# 6        107.0           75.0
# 7         89.0           10.0
# 36    103644.0         5457.0
# ...

# %%
df_sem_nan.to_csv("data/sample_yt_te_cross_with_topics.csv", index=False)

# %%
df_sem_nan["topic"].value_counts()
# Out:
# topic
# -1.0     19149
#  0.0     10227
#  1.0      8664
#  2.0      4057
#  3.0      3432
#          ...
#  56.0      120
#  57.0      117
#  58.0      112
#  59.0      108
#  60.0      106
# Name: count, Length: 62, dtype: int64
