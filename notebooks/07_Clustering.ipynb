# %% [markdown]
# # <center>Clustering of titles</center>
# ---

# %% [markdown]
# This code aims to cluster the titles of YouTube videos, trying to search for videos related to politics

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/youtube_titles.csv")
display(df)
# Out:
#            video_id                                              title  \
# 0       f2mR15dUDEY  The EU took huge steps in advancing the Green ...
# 1       dYlia_fQOLk        Die WHO - Im Griff der Lobbyisten - Doku HD
# 2       JufgN-CZR1k           Morning News NOW Full Broadcast – Dec. 1
# 3       ZIFDs3T-WHU  Vivek Ramaswamy: 'I have something that Trump ...
# 4       UHEm5Eifegs  Elon Lifts The Veil On The FAKE NEWS As Dems T...
# ...             ...                                                ...
# 325826  627tFhKT9xM              MILEI LEVA ARGENTINA PARA O NEOLÍTICO
# 325827  ES6V6FkxyEw  Taiwan Warns Former Military, Police Personnel...
# 325828  1C2brhy17g8                      Allianz, Kampania OFE Allianz
# 325829  8b-4mNN1o_I  'Glory to Hong Kong' Banned by Appeals Court |...
# 325830  xKQULTTnaI8  Amazing Grace with more than 200 bagpipes;  li...
#
#                                  youtube_video_link
# 0       https://www.youtube.com/watch?v=f2mR15dUDEY
# 1       https://www.youtube.com/watch?v=dYlia_fQOLk
# 2       https://www.youtube.com/watch?v=JufgN-CZR1k
# 3       https://www.youtube.com/watch?v=ZIFDs3T-WHU
# 4       https://www.youtube.com/watch?v=UHEm5Eifegs
# ...                                             ...
# 325826  https://www.youtube.com/watch?v=627tFhKT9xM
# 325827  https://www.youtube.com/watch?v=ES6V6FkxyEw
# 325828  https://www.youtube.com/watch?v=1C2brhy17g8
# 325829  https://www.youtube.com/watch?v=8b-4mNN1o_I
# 325830  https://www.youtube.com/watch?v=xKQULTTnaI8
#
# [325831 rows x 3 columns]
